# %% [markdown]
# # Aufgabe 1
#
# Nennen Sie die Syntax für eine while-Schleife! Kennzeichnen Sie den Schleifenkopf und den Schleifenrumpf!

# %%
# Aufgabe 1
for bedingung:  #Schleifenkopf
    anweisung1  #Schleifenrumpf

# %% [markdown]
# # Aufgabe 2
# Wie lange wird der Schleifenrumpf ausgeführt?

# %%
# Aufgabe 2
Wird solange ausgeführt, bis die bedingung erfüllt ist

# %% [markdown]
# # Aufgabe 3
#
# a) Warum wird zuerst "richtig" und dann "Das ist der else Zweig" ausgegeben?
#
# b) Was ist die Bedingung dafür, dass die Ausgabe "Das ist der else Zweig" erfolgt?
#
# ```Python
# x = True
# while x == True:
#     print("richtig")
#     x = False
# else:
#     print("Das ist der else Zweig")
# ```

# %%
# Aufgabe 3
# beim zweiten durchlauf ist der bool wert der x var auf False gesetzt daher wird die Schleife nicht durchlaufen und beendet

x = True
while x == True:
    print("richtig")
    x = False
else:
    print("Das ist der else Zweig")
# Out:
# richtig
# Das ist der else Zweig

# %% [markdown]
# # Aufgabe 4
#
# a) Wird die Anweisung nach continue ausgeführt?
#
# b) Wird die Anweisung nach break ausgeführt?
#
# c) Was macht continue?
#
# d) Was macht break? Wird else ausgeführt?
#
# ```Python
# while Bedingung:
#     bedingte Anweisung 1
#     if Bedingung 2:
#         continue
#         Anweisung nach continue
#     else:
#         break
#         Anweisung nach break
# else:
#     bedingte Anweisung 3
# unbedingte Anweisung1
# ````

# %%
import random
temperatur = ["kalt", "heiss", "normal", "error"]
random_temp = random.choice(temperatur)
while random_temp:
    random_temp = "kalt"
    if random_temp == "kalt":
        print("Es ist kalt!")
        random_temp = "heiss"
        continue
    elif random_temp == "heiss":
        print("Es ist heiss!")
        random_temp = "normal"
        continue
    elif temperatur == "normal":
        print("Es ist angenehm!")
        random_temp = "error"
        continue 
    else:
        random_temp == "error"
    print("Something went wrong!")
# Out:
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# Es ist kalt!
# ...

# %%
# Aufgabe 4
a) 
b) 
c) 
d)

# %% [markdown]
# # Aufgabe 5
#
# Schreiben Sie ein Programm, dass die Syntax aus Aufgabe 4 demonstriert!

# %%
# Aufgabe 5

# %% [markdown]
# # Aufgabe 6
#
# Nennen Sie die Syntax für eine for-Schleife!

# %%
# Aufgabe 6

# %% [markdown]
# # Aufgabe 7
#
# Schreiben Sie ein Programm, dass für jedes Element einer Liste folgende Werte ausgibt:
# - Wert
# - Datentyp
# - Speicherort
#
# liste1 = ["Herr", 1, 1.2, (0,1,2)]

# %%
# Aufgabe 7

# %% [markdown]
# # Aufgabe 8
#
# Gegeben sind zwei Tupel:
# - farbe_liste = ("Kreuz", "Pik", "Herz", "Karo")
# - wert_liste = ("Sieben", "Acht", "Neun", "Zehn", "Bube", "Dame", "König", "Ass").
#
# Geben Sie eine Liste aller möglichen Spielkarten aus:
#
#     1. Kreuz Sieben
#     ...
#     32. Karo Ass

# %%
# Aufgabe 8

# %% [markdown]
# # Aufgabe 9
# Bestimmen Sie die Menge aller möglichen Dreiecke mit einer ganzzahligen Kantenlänge von 1 - 20.
#
# Bitte bedenken Sie: Bei einem rechtwinkligem Dreieck (a, b, c) gilt: a² + b² = c².
#
# für welche werte a = 1-20, b = 1-20, c = 1-20 gilt a² + b² = c²

# %%
# Aufgabe 9

# %% [markdown]
# # Aufgabe 10
# Der Benutzer gibt eine Obergrenze und ein Untergrenze ein und das Programm ermittelt die Summe aller Werte zwischen den Grenzen, einschließlich der Grenzen.
#
# Untergrenze: 100
# Obergrenze: 200
# Die Gesamtsumme lautet: 15150

# %%
# Aufgabe 10

# %% [markdown]
# # Aufgabe 11
# Der Benutzer gibt Ganzzahhlen ein und zwar solange bis er 0 eingibt. Danach wird ihm die Anzahl der eingegebenen Zahlen und die Gesamtsumme aller Zahlen ausgegeben.
#
# Geben Sie einen Wert ein (0 - Ende): 12
# Geben Sie einen Wert ein (0 - Ende): 3
# Geben Sie einen Wert ein (0 - Ende): 454
# Geben Sie einen Wert ein (0 - Ende): 21
# Geben Sie einen Wert ein (0 - Ende): 0
# Summe: 490
# Anzahl: 4

# %%
# Lösung 11

# %% [markdown]
# # Aufgabe 12
# Schreiben Sie ein Programm, dass einen festen Pin-Code aus 4 Zahlen abfragt. Der Benutzer hat 3 mal die Möglichkeit einen Code einzugeben. Danach wird das Konto gesperrt.

# %%
# Aufgabe 12

# %% [markdown]
# # Aufgabe 13
#
# Eine Primzahl ist eine ganze Zahl, die ohne Rest nur durch 1 und sich selber teilbar ist. Schreiben Sie ein Programm, dass ermitteln, ob eine eingegebene Zahl eine Primazahl ist.
#
# - Zu testende Ganzzahl: 1234567891234567
# - Teiler: 47
# - Keine Primzahl

# %%
# Aufgabe 13
